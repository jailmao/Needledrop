# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("20-24.csv")

# %%
data.plot(x="popularity", y="rating", kind="scatter")
plt.xlabel("Popularity")
plt.ylabel("Rating")

plt.show()
